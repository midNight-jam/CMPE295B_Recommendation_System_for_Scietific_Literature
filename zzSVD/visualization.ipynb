# %%
import numpy as np
import matplotlib.pyplot as plt
import data

mat = data.read_and_create_user_LibCount()
libCount = mat[:, 0]
libCount.astype(int)
print(np.array_str(libCount))
plt.plot(libCount)
plt.xlabel('Users')
plt.ylabel('Papers in library')
plt.show()
# Out:
# [  0.  58.  32. ...,   9.  25.  19.]
