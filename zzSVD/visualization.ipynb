# %%
import numpy as np
import matplotlib.pyplot as plt
import data

mat = data.read_and_create_user_LibCount()
plt.plot(mat)
plt.xlabel('Users')
plt.ylabel('Papers in library')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-46340be340b7> in <module>()
#       3 import data
#       4
# ----> 5 mat = data.read_and_create_user_LibCount()
#       6 plt.plot(mat)
#       7 plt.xlabel('Users')
#
# /home/jayam/GIT/RepoNameTBD/zzSVD/data.py in read_and_create_user_LibCount()
#      64                 docs = line.split()
#      65                 first = docs.pop(0)
# ---> 66                 user_lib[user_id][0] = first
#      67                 user_id += 1
#      68
#
# IndexError: index 5551 is out of bounds for axis 0 with size 5551

# %%
import numpy as np
import matplotlib.pyplot as plt
import data

mat = data.read_and_create_paper_UserLibFreqCount()

plt.plot(mat)
plt.xlabel('Papers')
plt.ylabel('#Users')
plt.show()
